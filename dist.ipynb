# %% [markdown]
# <a href="https://colab.research.google.com/github/pkwbim/ai-learning/blob/master/dist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 有些分佈，可能是常態分佈的變型，所以我們可以算出偏度，利用偏度轉回常態分佈
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import boxcox_normmax, boxcox
from scipy.stats import skew
# %matplotlib inline
samples = np.random.normal(loc=10, scale=2, size=10000)
sns.distplot(samples)
print('skew', skew(samples))
boxcox_normmax(samples)
# Out:
# skew 0.03998515065625285
# 0.943999199153298

# %%
s = samples[samples > 0] + 1
new = s ** 5
sns.distplot(new)
print('skew', skew(new))
# Out:
# skew 2.5380326884954156

# %%
lamda = boxcox_normmax(new)
new2 = boxcox(new, lamda)
sns.distplot(new2)
