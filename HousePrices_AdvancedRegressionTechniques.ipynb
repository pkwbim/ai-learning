# %% [markdown]
# <a href="https://colab.research.google.com/github/pkwbim/ai-learning/blob/master/HousePrices_AdvancedRegressionTechniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
train_df = pd.read_csv("train.csv", encoding="utf-8")
test_df = pd.read_csv("test.csv", encoding="utf-8")
train_df
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
test_df
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 80 columns]

# %%
datas = pd.concat([train_df, test_df])
datas
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal  208500.0
# 1        2          20       RL  ...        WD         Normal  181500.0
# 2        3          60       RL  ...        WD         Normal  223500.0
# 3        4          70       RL  ...        WD        Abnorml  140000.0
# 4        5          60       RL  ...        WD         Normal  250000.0
# ...    ...         ...      ...  ...       ...            ...       ...
# 1454  2915         160       RM  ...        WD         Normal       NaN
# 1455  2916         160       RM  ...        WD        Abnorml       NaN
# 1456  2917          20       RL  ...        WD        Abnorml       NaN
# 1457  2918          85       RL  ...        WD         Normal       NaN
# 1458  2919          60       RL  ...        WD         Normal       NaN
#
# [2919 rows x 81 columns]

# %%
# drop not important field
datas = datas.drop(["Id",'SalePrice'], axis=1)
datas
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0             60       RL         65.0  ...    2008       WD        Normal
# 1             20       RL         80.0  ...    2007       WD        Normal
# 2             60       RL         68.0  ...    2008       WD        Normal
# 3             70       RL         60.0  ...    2006       WD       Abnorml
# 4             60       RL         84.0  ...    2008       WD        Normal
# ...          ...      ...          ...  ...     ...      ...           ...
# 1454         160       RM         21.0  ...    2006       WD        Normal
# 1455         160       RM         21.0  ...    2006       WD       Abnorml
# 1456          20       RL        160.0  ...    2006       WD       Abnorml
# 1457          85       RL         62.0  ...    2006       WD        Normal
# 1458          60       RL         74.0  ...    2006       WD        Normal
#
# [2919 rows x 79 columns]

# %%
# 補型態的缺
type_fields = ["MSSubClass",'MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','OverallCond','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition']
for field in type_fields:
  most = datas[field].value_counts().idxmax()
  datas[field] = datas[field].fillna(most)
datas
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0             60       RL         65.0  ...    2008       WD        Normal
# 1             20       RL         80.0  ...    2007       WD        Normal
# 2             60       RL         68.0  ...    2008       WD        Normal
# 3             70       RL         60.0  ...    2006       WD       Abnorml
# 4             60       RL         84.0  ...    2008       WD        Normal
# ...          ...      ...          ...  ...     ...      ...           ...
# 1454         160       RM         21.0  ...    2006       WD        Normal
# 1455         160       RM         21.0  ...    2006       WD       Abnorml
# 1456          20       RL        160.0  ...    2006       WD       Abnorml
# 1457          85       RL         62.0  ...    2006       WD        Normal
# 1458          60       RL         74.0  ...    2006       WD        Normal
#
# [2919 rows x 79 columns]

# %%
# 做 one-hot
datas = pd.get_dummies(datas, columns=type_fields)
datas
# Out:
#       LotFrontage  LotArea  ...  SaleCondition_Normal  SaleCondition_Partial
# 0            65.0     8450  ...                     1                      0
# 1            80.0     9600  ...                     1                      0
# 2            68.0    11250  ...                     1                      0
# 3            60.0     9550  ...                     0                      0
# 4            84.0    14260  ...                     1                      0
# ...           ...      ...  ...                   ...                    ...
# 1454         21.0     1936  ...                     1                      0
# 1455         21.0     1894  ...                     0                      0
# 1456        160.0    20000  ...                     0                      0
# 1457         62.0    10441  ...                     1                      0
# 1458         74.0     9627  ...                     1                      0
#
# [2919 rows x 311 columns]

# %%
#補數值的缺失值
#略
datas = datas.fillna(datas.median())
datas
# Out:
#       LotFrontage  LotArea  ...  SaleCondition_Normal  SaleCondition_Partial
# 0            65.0     8450  ...                     1                      0
# 1            80.0     9600  ...                     1                      0
# 2            68.0    11250  ...                     1                      0
# 3            60.0     9550  ...                     0                      0
# 4            84.0    14260  ...                     1                      0
# ...           ...      ...  ...                   ...                    ...
# 1454         21.0     1936  ...                     1                      0
# 1455         21.0     1894  ...                     0                      0
# 1456        160.0    20000  ...                     0                      0
# 1457         62.0    10441  ...                     1                      0
# 1458         74.0     9627  ...                     1                      0
#
# [2919 rows x 311 columns]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# 取列: iloc(看實際是第幾列), loc(看列標籤)
# [第一列, 第二列....]
x_train = datas.iloc[:len(train_df)]
x_predict = datas.iloc[len(train_df):]
y_train = train_df["SalePrice"]
scaler = MinMaxScaler()
datas_scale = pd.DataFrame(scaler.fit_transform(datas), columns=datas.columns)
x_train_scale = datas_scale.iloc[:len(train_df)]
x_test_scale = datas_scale.iloc[len(train_df):]
x_train_scale
# Out:
#       LotFrontage   LotArea  ...  SaleCondition_Normal  SaleCondition_Partial
# 0        0.150685  0.033420  ...                   1.0                    0.0
# 1        0.202055  0.038795  ...                   1.0                    0.0
# 2        0.160959  0.046507  ...                   1.0                    0.0
# 3        0.133562  0.038561  ...                   0.0                    0.0
# 4        0.215753  0.060576  ...                   1.0                    0.0
# ...           ...       ...  ...                   ...                    ...
# 1455     0.140411  0.030929  ...                   1.0                    0.0
# 1456     0.219178  0.055505  ...                   1.0                    0.0
# 1457     0.154110  0.036187  ...                   1.0                    0.0
# 1458     0.160959  0.039342  ...                   1.0                    0.0
# 1459     0.184932  0.040370  ...                   1.0                    0.0
#
# [1460 rows x 311 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.tree import DecisionTreeRegressor

# %%
rf = RandomForestRegressor(random_state = 0)
params = {
    "max_depth":range(5, 10),
    'n_estimators': range(5, 10)
}
grid = GridSearchCV(rf, params, cv=10, n_jobs=-1, scoring='r2')
grid.fit(x_train_scale, y_train)
best2 = grid.best_estimator_

print("最佳參數:", grid.best_params_)
print("最佳分數:", grid.best_score_)
# Out:
# 最佳參數: {'max_depth': 17, 'n_estimators': 8}
# 最佳分數: 0.8370907999097768

# %%
# Instantiate model with 1000 decision trees
# 最佳參數: {'max_depth': 17, 'n_estimators': 8}
rf = RandomForestRegressor(n_estimators = grid.best_params_['n_estimators'], 
                max_depth=grid.best_params_['max_depth'] 
              )
# Train the model on training data
c = cross_val_score(rf, x_train_scale, y_train, cv=10, scoring='r2')
print(c)
rf.fit(x_train_scale, y_train)
pre = rf.predict(x_test_scale)
pid = test_df["Id"]
result = pd.DataFrame({
    "Id":pid,
    "SalePrice":pre
})
result.to_csv("result_dtr.csv", encoding="utf-8", index=False)
result
# Out:
# [0.83779358 0.87628256 0.92609438 0.71154314 0.85697055 0.87587816
#  0.88658585 0.8662406  0.72293742 0.81058176]
#         Id      SalePrice
# 0     1461  132614.285714
# 1     1462  145687.500000
# 2     1463  178417.500000
# 3     1464  178562.175325
# 4     1465  209687.500000
# ...    ...            ...
# 1454  2915   85875.000000
# 1455  2916   88604.166667
# 1456  2917  156900.000000
# 1457  2918  122487.500000
# 1458  2919  220125.000000
#
# [1459 rows x 2 columns]
